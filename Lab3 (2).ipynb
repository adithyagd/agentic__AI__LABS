# %%
# !pip install langchain-groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.0 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(api_key=" ",

               model="llama-3.1-8b-instant", temperature=0.3)

# %%
task = 'Write a short polite email asking my professor for a deadline extension.'

draft = llm.invoke(task).content

print('----- DRAFT EMAIL -----')

print(draft)
# Out:
# ----- DRAFT EMAIL -----
# Subject: Request for Deadline Extension for [Assignment/Project]
#
# Dear Professor [Professor's Name],
#
# I hope this email finds you well. I am writing to request a deadline extension for the [Assignment/Project] that is due on [Original Due Date]. Due to [briefly mention a valid reason, e.g., unforeseen circumstances, academic commitments, or personal issues], I require some additional time to complete the assignment to the best of my abilities.
#
# I am confident that with a brief extension, I will be able to submit high-quality work that meets your expectations. I am estimating that I will need [Specific Number of Days] to complete the assignment, and I am requesting a new due date of [Proposed New Due Date].
#
# I would greatly appreciate it if you could consider my request. If there is any additional information you need from me or if you require a meeting to discuss this further, please let me know.
#
# Thank you for your understanding and support.
#
# Sincerely,
# [Your Name]

# %%
decision = input('Type APPROVED to send, or anything else to reject: ')



if decision.strip().upper() == 'APPROVED':

    print('✅ Email sent!')   # in a real app, sending happens here

else:

    print('❌ Not sent. The draft was rejected.')
# Out:
# Type APPROVED to send, or anything else to reject: APPROVED
# ✅ Email sent!

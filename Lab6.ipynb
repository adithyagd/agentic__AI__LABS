# %%
# !pip install pyautogen -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 5.0 MB/s eta 0:00:00

# %%
config_list = [{

    'model': 'llama-3.1-8b-instant',

    'api_key': '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',

    'base_url': 'https://api.groq.com/openai/v1'

}]

llm_config = {'config_list': config_list, 'temperature': 0.4}

# %%
import autogen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1834/2905596045.py in <cell line: 0>()
# ----> 1 import autogen
#
# ModuleNotFoundError: No module named 'autogen'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
